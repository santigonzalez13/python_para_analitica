# %% [markdown]
# # Dataframes

# %% [markdown]
# ### Introducción a pandas y DataFrames
#
# Pandas es una biblioteca de Python diseñada para trabajar con datos estructurados de forma fácil y eficiente. Los `DataFrame` son estructuras de datos bidimensionales con columnas de diferentes tipos, algo parecido a una hoja de cálculo o una tabla SQL.
#
# ### Instalación de pandas
#
# Para comenzar a trabajar con pandas, primero necesitas instalar la biblioteca. Esto se puede hacer fácilmente utilizando pip:
#
# ```bash
# pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2. Creación de un DataFrame
#
# # Creación de un DataFrame
#
# Los DataFrames pueden ser creados de múltiples maneras, aquí veremos cómo crear uno desde un diccionario de listas.

# %%
# Datos en un diccionario
data = {
  'Nombre': ['Ana', 'Luis', 'Carlos'],
  'Edad': [25, 30, 35],
  'Ciudad': ['Madrid', 'Barcelona', 'Valencia']
}

# Creación del DataFrame
df = pd.DataFrame(data)

# Mostrar el DataFrame
print(df)
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    35   Valencia

# %%
df
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    35   Valencia

# %% [markdown]
# ### 3. Acceso a los datos en un DataFrame
#
# #### Acceso a los datos en un DataFrame
#
# Puedes acceder a los datos de un DataFrame de varias maneras, incluyendo por columnas, filas, o celdas específicas.
#
# #### Acceso por columnas

# %%
# Acceso a la columna 'Nombre'
print(df["Nombre"])
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# Name: Nombre, dtype: object

# %% [markdown]
# #### Acceso por filas
#
# Puedes acceder a las filas utilizando `.loc` para etiquetas de índices o `.iloc` para posiciones de índices.

# %%
# Acceso a la primera fila usando iloc
print(df.iloc[0])
# Out:
# Nombre       Ana
# Edad          25
# Ciudad    Madrid
# Name: 0, dtype: object

# %%
# Acceso a la fila con índice '0' usando loc (si el índice es personalizado)
print(df.loc[0])
# Out:
# Nombre       Ana
# Edad          25
# Ciudad    Madrid
# Name: 0, dtype: object

# %% [markdown]
# ### Operaciones Básicas con Dataframes
#
#
# Los DataFrames permiten realizar varias operaciones de manipulación de datos, como agregar columnas, eliminar filas, etc.

# %%
# Agregar una nueva columna
df['Profesión'] = ['Ingeniera', 'Arquitecto', 'Médico']
print(df)
# Out:
#    Nombre  Edad     Ciudad   Profesión
# 0     Ana    25     Madrid   Ingeniera
# 1    Luis    30  Barcelona  Arquitecto
# 2  Carlos    35   Valencia      Médico

# %%
# Eliminar una fila

df.drop(1, inplace=True)
print(df)

df.reset_index(drop=True)
# Out:
#    Nombre  Edad    Ciudad  Profesión
# 0     Ana    25    Madrid  Ingeniera
# 2  Carlos    35  Valencia     Médico
#    Nombre  Edad    Ciudad  Profesión
# 0     Ana    25    Madrid  Ingeniera
# 1  Carlos    35  Valencia     Médico

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     2 non-null      object
#  1   Edad       2 non-null      int64
#  2   Ciudad     2 non-null      object
#  3   Profesión  2 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 196.0+ bytes

# %%
# Eliminar una columna

df.drop('Nombre', axis=1, inplace= True)
print(df)
# Out:
#    Edad    Ciudad  Profesión
# 0    25    Madrid  Ingeniera
# 2    35  Valencia     Médico

# %% [markdown]
# Pandas facilita guardar tu DataFrame en diferentes formatos, como CSV, Excel, entre otros. También puedes cargar tus datos desde estos formatos.

# %%
df.to_csv('datos.csv')

# %%
#df_cargado = pd.read_csv('.csv') #Seleccione cualquiera
#print(df_cargado)

# %%
df_cargado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789 entries, 0 to 788
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   f_distancia      789 non-null    float64
#  1   f_velMax         789 non-null    float64
#  2   k_ruta           789 non-null    int64
#  3   k_dispositivo    789 non-null    object
#  4   o_lat_final      789 non-null    float64
#  5   o_lng_final      789 non-null    float64
#  6   o_lat_inicial    789 non-null    float64
#  7   o_lng_inicial    789 non-null    float64
#  8   o_fecha_inicial  789 non-null    object
#  9   o_fecha_final    789 non-null    object
#  10  o_IdCliente      9 non-null      object
#  11  n_usuario        695 non-null    object
#  12  Identificacion   695 non-null    float64
#  13  MARCA            686 non-null    object
#  14  Referencia       686 non-null    object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 92.6+ KB

# %%
df_cargado.drop("n_usuario", axis=1, inplace=True)

# %% [markdown]
# ## Exploración básica de Dataframe

# %%
df_cargado.tail()
# Out:
#      f_distancia  f_velMax   k_ruta k_dispositivo  o_lat_final  o_lng_final  \
# 784        0.000       0.0  1367570       Xch1663     4.635107   -74.069747
# 785        0.000       0.0  1367557       Xch1605     4.689089   -74.186089
# 786      532.361      10.0  1367556       Xch1531     4.662642   -74.059089
# 787        0.000       0.0  1367551       Xch1574     4.656715   -74.069071
# 788     1235.930       1.0  1367547       Xch1545     4.685452   -74.056840
#
#      o_lat_inicial  o_lng_inicial      o_fecha_inicial        o_fecha_final  \
# 784       4.635107     -74.069747  2024-08-23 00:32:17  2024-08-23 00:32:17
# 785       4.689089     -74.186089  2024-08-23 00:16:04  2024-08-23 00:16:04
# 786       4.666770     -74.056658  2024-08-23 00:14:35  2024-08-23 00:24:26
# 787       4.656715     -74.069071  2024-08-23 00:09:35  2024-08-23 00:09:35
# 788       4.676258     -74.050573  2024-08-23 00:07:30  2024-08-23 00:10:35
#
#     o_IdCliente  Identificacion               MARCA  \
# 784         NaN       6958249.0  Guajira Bike Proto
# 785         NaN       1420102.0             Guajira
# 786         NaN             NaN                 NaN
# 787           .       2749046.0             Guajira
# 788         NaN       3201966.0             Guajira
#
#                                             Referencia
# 784  Serial marco: ha12437174 // Serial motor: 2308...
# 785                               211710701//23080038
# 786                                                NaN
# 787                                          Pendiente
# 788                                      Motor22060069

# %%
df_cargado.describe()
# Out:
#          f_distancia    f_velMax        k_ruta  o_lat_final  o_lng_final  \
# count     789.000000  789.000000  7.890000e+02   789.000000   789.000000
# mean     5834.786840   24.139797  1.369168e+06     4.628250   -74.092116
# std     23470.344859   18.856669  8.723227e+02     0.333406     0.246311
# min         0.000000    0.000000  1.367547e+06     1.610387   -79.176960
# 25%       360.933000    7.000000  1.368445e+06     4.654803   -74.067827
# 50%      2422.720000   28.000000  1.369171e+06     4.669448   -74.056982
# 75%      6475.960000   35.000000  1.369939e+06     4.676134   -74.049613
# max    630327.000000  211.000000  1.370664e+06     4.747252   -74.019333
#
#        o_lat_inicial  o_lng_inicial  Identificacion
# count     789.000000     789.000000    6.950000e+02
# mean        4.630834     -74.085763    1.948053e+08
# std         0.325205       0.166739    3.979758e+08
# min         1.610522     -75.612409    5.177070e+05
# 25%         4.654901     -74.067778    3.201966e+06
# 50%         4.669342     -74.056982    5.628219e+06
# 75%         4.676153     -74.049636    7.639612e+06
# max         4.747238     -74.019951    1.127614e+09

# %%
df_cargado
# Out:
#      f_distancia  f_velMax   k_ruta k_dispositivo  o_lat_final  o_lng_final  \
# 0          0.000       0.0  1370664       Xch1674     4.675718   -74.046311
# 1     630327.000     187.0  1370650       Xch1542     2.590965   -79.176960
# 2        119.903       4.0  1370647       Xch1757     4.655013   -74.064302
# 3          0.000       1.0  1370646       Xch1762     4.732695   -74.090218
# 4       5388.270      35.0  1370638       Xch1607     4.668328   -74.065867
# ..           ...       ...      ...           ...          ...          ...
# 784        0.000       0.0  1367570       Xch1663     4.635107   -74.069747
# 785        0.000       0.0  1367557       Xch1605     4.689089   -74.186089
# 786      532.361      10.0  1367556       Xch1531     4.662642   -74.059089
# 787        0.000       0.0  1367551       Xch1574     4.656715   -74.069071
# 788     1235.930       1.0  1367547       Xch1545     4.685452   -74.056840
#
#      o_lat_inicial  o_lng_inicial      o_fecha_inicial        o_fecha_final  \
# 0         4.675718     -74.046311  2024-08-23 23:52:08  2024-08-23 23:52:08
# 1         4.599059     -74.207040  2024-08-23 23:38:25  2024-08-23 23:53:46
# 2         4.655357     -74.063982  2024-08-23 23:36:06  2024-08-23 23:50:53
# 3         4.732695     -74.090218  2024-08-23 23:35:41  2024-08-23 23:35:41
# 4         4.669572     -74.054320  2024-08-23 23:24:40  2024-08-23 23:42:02
# ..             ...            ...                  ...                  ...
# 784       4.635107     -74.069747  2024-08-23 00:32:17  2024-08-23 00:32:17
# 785       4.689089     -74.186089  2024-08-23 00:16:04  2024-08-23 00:16:04
# 786       4.666770     -74.056658  2024-08-23 00:14:35  2024-08-23 00:24:26
# 787       4.656715     -74.069071  2024-08-23 00:09:35  2024-08-23 00:09:35
# 788       4.676258     -74.050573  2024-08-23 00:07:30  2024-08-23 00:10:35
#
#     o_IdCliente                  n_usuario  Identificacion  \
# 0           NaN  Jose Enrique Sifontes Ram    4.498934e+06
# 1           NaN  Betzy Waleska Carmona Adr    1.052536e+06
# 2           NaN  Albert Daniel valrdeve co    1.010112e+09
# 3           NaN                        NaN             NaN
# 4           NaN  Maykol Stiven Lizcano Vel    5.056286e+06
# ..          ...                        ...             ...
# 784         NaN  Ruben Ricardo Bravo Ojeda    6.958249e+06
# 785         NaN    Luis Maldonado Ordóñez     1.420102e+06
# 786         NaN                        NaN             NaN
# 787           .  Wilder Fernando  Girand L    2.749046e+06
# 788         NaN   Luis Gerardo Garcia Gali    3.201966e+06
#
#                         MARCA  \
# 0    Guajira Bike EBike Green
# 1                     Guajira
# 2    Guajira Bike EBike White
# 3                         NaN
# 4          Guajira Bike Black
# ..                        ...
# 784        Guajira Bike Proto
# 785                   Guajira
# 786                       NaN
# 787                   Guajira
# 788                   Guajira
#
#                                             Referencia
# 0    Serial del marco : ha2325786 Serial motor 2325786
# 1                                        Motor22060045
# 2        Serial marco  ha12439169 Serial motor 2308005
# 3                                                  NaN
# 4                                 Serial de marco gf21
# ..                                                 ...
# 784  Serial marco: ha12437174 // Serial motor: 2308...
# 785                               211710701//23080038
# 786                                                NaN
# 787                                          Pendiente
# 788                                      Motor22060069
#
# [789 rows x 15 columns]

# %%
from matplotlib import pyplot as plt
df_cargado['f_distancia'].plot(kind='hist', bins=20, title='f_distancia')
plt.gca().spines[['top', 'right',]].set_visible(False)
